# %%
import random
import numpy
import numpy as np
import csv
from deap import tools
import os
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
PATH_EXAMPLE_DATASET = 'data'

# %%
PATH_DATASET =  os.path.join(PATH_EXAMPLE_DATASET, 'wav75_ex1_.csv')

# %%
PATH_DATASET
# Out:
# 'data/wav75_ex1_.csv'

# %%
df = pd.read_csv(PATH_DATASET, header = None)

# %% [markdown]
# Balance dataset with pandas

# %%
data_columns = list(range(0,75))
#label_column = 76
label_column = 75
test_size = 0.3
classes = df[label_column].unique()
balance = 1

# %%
df_splits = []
for cl in classes:
    df_splits.append(df.drop(df.index[df[label_column] == cl]))

#df_class0 = df.drop(df.index[df[label_column] == 0])
#df_class1 = df.drop(df.index[df[label_column] == 1])

# %%
minor_class_len = min([x.shape[0] for x in df_splits])

if balance:
    df_splits_balanced = []
    for split in df_splits:
        df_splits_balanced.append(split.sample(n = minor_class_len))
    
    df_splits = df_splits_balanced

df_train = []
df_test  = []
for split in df_splits:
    t1, t2 = train_test_split(split, test_size = test_size)
    df_train.append(t1)
    df_test.append(t2)

# %%
test = pd.concat(df_test)
train = pd.concat(df_train)

# %%
test[data_columns]
# Out:
#            0         1         2         3         4         5         6   \
# 328  0.020745  0.019145  0.002503  0.018080  0.039778 -0.027152  0.022497
# 424  0.044135  0.039179  0.010475  0.021541  0.046629 -0.044901  0.028457
# 309  0.027719  0.027915  0.005346  0.017899  0.046489 -0.023916  0.019506
# 218 -0.039311  0.038334  0.010077  0.026338 -0.045170  0.028151  0.027519
# 332 -0.024578  0.024083  0.003982  0.018871 -0.043953  0.023953  0.018910
# 496 -0.020352  0.019806  0.002683  0.016396 -0.042214  0.024938  0.017249
# 423  0.002924  0.008644  0.000514  0.015344  0.009929  0.007784  0.016900
# 487 -0.001130  0.005322  0.000195  0.010772 -0.000651  0.004009  0.014280
# 276  0.000804  0.007315  0.000369  0.015016 -0.000114  0.000687  0.019692
# 413  0.020195  0.019888  0.002704  0.016922  0.041390 -0.019298  0.018755
# 417 -0.016387  0.016394  0.001837  0.014552 -0.041360  0.014644  0.015842
# 198 -0.016032  0.015785  0.001713  0.019110 -0.031096  0.004822  0.020851
# 574 -0.002682  0.005710  0.000224  0.011943 -0.000954  0.002466  0.014475
# 412 -0.012358  0.012899  0.001142  0.014874 -0.033385  0.014525  0.014937
# 770  0.004119  0.007379  0.000375  0.011762  0.015746 -0.004153  0.012638
# 197 -0.006639  0.010423  0.000746  0.019621 -0.010863  0.006974  0.019821
# 205 -0.017867  0.017507  0.002100  0.018578 -0.038100  0.018791  0.018914
# 63  -0.268877  0.244626  0.409985  0.106871 -0.047274  0.263170  0.144992
# 659 -0.027613  0.025691  0.004507  0.017818 -0.044846  0.020291  0.020871
# 651 -0.020323  0.019277  0.002540  0.016542 -0.042138  0.017298  0.017940
# 245  0.008004  0.012450  0.001065  0.019829  0.020534 -0.003345  0.019890
# 554  0.000061  0.005908  0.000240  0.013139 -0.000631  0.005114  0.013671
# 873 -0.041097  0.037000  0.009346  0.019662 -0.046602  0.041404  0.025348
# 616  0.017192  0.014568  0.001448  0.014916  0.036826 -0.017032  0.017122
#
#            7         8         9     ...           65        66        67  \
# 328  0.003109  0.023731 -0.011536    ...     0.003523  0.026557  0.006299
# 424  0.004906  0.021535 -0.047395    ...    -0.029031  0.037968  0.012652
# 309  0.002316  0.018071 -0.033640    ...    -0.050686  0.039749  0.014009
# 218  0.004627  0.024060  0.029747    ...    -0.038934  0.034978  0.008530
